# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread("/content/ct.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1329x1600>

# %%
b_img = cv2.resize(image, (image.shape[1] // 10, image.shape[0] // 10), interpolation=cv2.INTER_AREA)
b_img = cv2.resize(b_img, (image.shape[1], image.shape[0]), interpolation=cv2.INTER_NEAREST)

cv2_imshow(b_img)
# Out:
# <PIL.Image.Image image mode=RGB size=1329x1600>
